# %%
def dfs(graph, start):

    visited = set()


    order = []


    def explore(node):


        visited.add(node)


        order.append(node)

        for neighbor in graph[node]:


            if neighbor not in visited:
                explore(neighbor)


    explore(start)


    return order, visited



graph = {
    "A": ["B", "C"],
    "B": ["A", "D"],
    "C": ["A", "D", "E"],
    "D": ["B", "C", "F"],
    "E": ["C"],
    "F": ["D"],
    "G": ["H"],
    "H": []
}

start = "A"

from collections import deque

def bfs(graph, start):
    visited = set()
    order = []
    queue = deque([start])

    visited.add(start)

    while queue:
        node = queue.popleft()
        order.append(node)

        for neighbor in graph[node]:
            if neighbor not in visited:
                visited.add(neighbor)
                queue.append(neighbor)

    return order, visited



order_bfs, visited_bfs = bfs(graph, start)

print("BFS visiting order:", order_bfs)
print("Count of visited nodes:", len(visited_bfs))
print("Non-visited nodes:", set(graph.keys()) - visited_bfs)


order, visited = dfs(graph, start)

print("DFS  visiting order:", order)
print("Count of  visited nodes:", len(visited))
print("Non-visited nodes:", set(graph.keys()) - visited)
# Out:
# BFS visiting order: ['A', 'B', 'C', 'D', 'E', 'F']
# Count of visited nodes: 6
# Non-visited nodes: {'G', 'H'}
# DFS  visiting order: ['A', 'B', 'D', 'C', 'E', 'F']
# Count of  visited nodes: 6
# Non-visited nodes: {'G', 'H'}
